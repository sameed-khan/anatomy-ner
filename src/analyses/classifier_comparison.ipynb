# %%
import re
import spacy
import polars as pl
import numpy as np

from spacy.lang.en import STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression

pl.Config.set_tbl_cols(10)
pl.Config.set_tbl_rows(100)
# Out:
# polars.config.Config

# %% [markdown]
# ### Import and Preprocessing

# %%
dataset = pl.read_csv("../../data/eval_dataset_2000.tsv", separator="\t")
dataset.head()
# Out:
# shape: (5, 7)
# ┌───────────────┬────────────┬──────────────┬──────────────┬──────────────┬──────────────┬─────────┐
# │ filename      ┆ patient_id ┆ finding      ┆ anatomic_cla ┆ possible_sec ┆ autogenerate ┆ labeled │
# │ ---           ┆ ---        ┆ ---          ┆ ssification  ┆ ondary       ┆ d            ┆ ---     │
# │ str           ┆ str        ┆ str          ┆ ---          ┆ ---          ┆ ---          ┆ bool    │
# │               ┆            ┆              ┆ str          ┆ str          ┆ bool         ┆         │
# ╞═══════════════╪════════════╪══════════════╪══════════════╪══════════════╪══════════════╪═════════╡
# │ /home/khans24 ┆ p10394761  ┆ PA and       ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ lateral      ┆ S            ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ chest views  ┆              ┆              ┆              ┆         │
# │               ┆            ┆ wer…         ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ Analysis is  ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ performed in ┆ S            ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ direc…       ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ There is     ┆ CARDIAC/CARD ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ mild cardiac ┆ IOMEDIASTINA ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ enlargem…    ┆ LSILHO…      ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ There is  a  ┆ CARDIAC/CARD ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ relative     ┆ IOMEDIASTINA ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ prominenc…   ┆ LSILHO…      ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ The          ┆ CARDIAC/CARD ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ thoracic     ┆ IOMEDIASTINA ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ aorta is     ┆ LSILHO…      ┆              ┆              ┆         │
# │               ┆            ┆ general…     ┆              ┆              ┆              ┆         │
# └───────────────┴────────────┴──────────────┴──────────────┴──────────────┴──────────────┴─────────┘

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def preprocess_text(text: str) -> str:
    """ Perform text preprocessing on the corpus of text in the given column of the dataframe. """
    # Remove punctuation, replace with empty space and then replace all double or more spaces with one space
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s{2,}', ' ', text)
    return text
    # doc = nlp(text)
    # result = []
    # for sentence in doc.sentences:
    #     for word in sentence.words:
    #         if word.text.lower() not in stop_words and word.upos in ["NOUN", "VERB", "ADJ", "ADV"]:
    #             result.append(word.lemma.lower())

dataset = dataset.with_columns(
    pl.col("finding").map_elements(lambda s: preprocess_text(s), return_dtype=pl.String)
)

# %%
doc = list(nlp.pipe(dataset["finding"], disable=["tok2vec", "parser", "senter", "ner"]))

# %%
allsentences = []
for sentence in doc:
    allsentences.append(
        ' '.join([token.lemma_ for token in sentence if token.text not in STOP_WORDS])
    )

# %%
dataset = dataset.with_columns(pl.Series("preprocessed_finding", allsentences))

# %% [markdown]
# ### Classification

# %%
dataset = dataset.with_columns(
    pl.when(
        (pl.col("anatomic_classification") == "BOWEL") |
        (pl.col("anatomic_classification") == "SPLEEN") |
        (pl.col("anatomic_classification") == "GALLBLADDER") |
        (pl.col("anatomic_classification") == "STOMACH")
    )
        .then(pl.lit("ABDOMEN"))
        .otherwise(pl.col("anatomic_classification"))
    .alias("anatomic_classification")
)

dataset.select(
    pl.col("anatomic_classification").value_counts(sort=True)
).unnest("anatomic_classification")
# Out:
# shape: (8, 2)
# ┌─────────────────────────────────┬───────┐
# │ anatomic_classification         ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ LUNG/PLEURA/LARGE AIRWAYS       ┆ 921   │
# │ LINES/TUBES/DRAINS              ┆ 439   │
# │ CARDIAC/CARDIOMEDIASTINALSILHO… ┆ 329   │
# │ MISCELLANEOUS                   ┆ 292   │
# │ BONE AND SOFT TISSUE            ┆ 124   │
# │ POSITIONING/LIMITATIONS         ┆ 99    │
# │ ABDOMEN                         ┆ 22    │
# │ NECK                            ┆ 4     │
# └─────────────────────────────────┴───────┘

# %%
le = LabelEncoder()
le.fit(dataset.filter(( pl.col("anatomic_classification") != "NECK" ) & (pl.col("anatomic_classification") != "ABDOMEN"))["anatomic_classification"])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['BONE AND SOFT TISSUE', 'CARDIAC/CARDIOMEDIASTINALSILHOUETTE',
#        'LINES/TUBES/DRAINS', 'LUNG/PLEURA/LARGE AIRWAYS', 'MISCELLANEOUS',
#        'POSITIONING/LIMITATIONS'], dtype='<U35')

# %%
encoder = TfidfVectorizer()
kf = KFold(n_splits=10, shuffle=True, random_state=1026)
filterset = dataset.filter(( pl.col("anatomic_classification") != "NECK" ) & (pl.col("anatomic_classification") != "ABDOMEN"))
clf = LogisticRegression()
accuracies = []
reports = []
for tridx, tsidx in kf.split(filterset, groups=filterset["anatomic_classification"]):
    train = filterset.select(
        pl.col("anatomic_classification").gather(tridx),
        pl.col("preprocessed_finding").gather(tridx)
    ).with_columns(
        pl.col("anatomic_classification").map_elements(lambda s: le.transform([s])[0], return_dtype=pl.Int32)
        .alias("anatomic_classification")
    )
    test = filterset.select(
        pl.col("anatomic_classification").gather(tsidx),
        pl.col("preprocessed_finding").gather(tsidx)
    ).with_columns(
        pl.col("anatomic_classification").map_elements(lambda s: le.transform([s])[0], return_dtype=pl.Int32)
        .alias("anatomic_classification")
    )

    train_encodings = encoder.fit_transform(train["preprocessed_finding"])
    test_encodings = encoder.transform(test["preprocessed_finding"])
    y_true = test["anatomic_classification"]

    clf.fit(train_encodings, train["anatomic_classification"])
    y_pred = clf.predict(test_encodings)
    y_probas = clf.predict_proba(test_encodings)
    accuracies.append(accuracy_score(y_true, y_pred))
    reports.append(classification_report(y_true, y_pred, target_names=le.classes_))

    print(classification_report(y_true, y_pred, target_names=le.classes_))
# Out:
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       1.00      0.56      0.72        16
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.76      0.79      0.77        28
#                  LINES/TUBES/DRAINS       0.90      0.86      0.88        50
#           LUNG/PLEURA/LARGE AIRWAYS       0.78      0.98      0.86        85
#                       MISCELLANEOUS       0.85      0.53      0.65        32
#             POSITIONING/LIMITATIONS       0.75      0.60      0.67        10
#
#                            accuracy                           0.81       221
#                           macro avg       0.84      0.72      0.76       221
#                        weighted avg       0.83      0.81      0.81       221
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       0.91      0.71      0.80        14
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.92      0.82      0.87        40
#                  LINES/TUBES/DRAINS       1.00      0.89      0.94        53
#           LUNG/PLEURA/LARGE AIRWAYS       0.80      0.92      0.86        77
#                       MISCELLANEOUS       0.81      0.83      0.82        30
#             POSITIONING/LIMITATIONS       0.71      0.71      0.71         7
#
#                            accuracy                           0.86       221
#                           macro avg       0.86      0.82      0.83       221
#                        weighted avg       0.87      0.86      0.87       221
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       1.00      0.75      0.86        12
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.86      0.74      0.79        34
#                  LINES/TUBES/DRAINS       0.86      0.91      0.89        34
#           LUNG/PLEURA/LARGE AIRWAYS       0.80      0.93      0.86        91
#                       MISCELLANEOUS       0.70      0.61      0.66        31
#             POSITIONING/LIMITATIONS       0.93      0.68      0.79        19
#
#                            accuracy                           0.82       221
#                           macro avg       0.86      0.77      0.81       221
#                        weighted avg       0.83      0.82      0.82       221
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       0.89      0.47      0.62        17
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.88      0.64      0.74        33
#                  LINES/TUBES/DRAINS       0.93      0.95      0.94        40
#           LUNG/PLEURA/LARGE AIRWAYS       0.81      0.95      0.87        96
#                       MISCELLANEOUS       0.68      0.68      0.68        25
#             POSITIONING/LIMITATIONS       0.89      0.80      0.84        10
#
#                            accuracy                           0.83       221
#                           macro avg       0.84      0.75      0.78       221
#                        weighted avg       0.83      0.83      0.82       221
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       1.00      0.83      0.91        12
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.97      0.88      0.93        43
#                  LINES/TUBES/DRAINS       0.92      0.95      0.94        38
#           LUNG/PLEURA/LARGE AIRWAYS       0.89      0.98      0.93        89
#                       MISCELLANEOUS       0.90      0.84      0.87        31
#             POSITIONING/LIMITATIONS       0.80      0.57      0.67         7
#
#                            accuracy                           0.91       220
#                           macro avg       0.91      0.84      0.87       220
#                        weighted avg       0.92      0.91      0.91       220
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       0.89      0.57      0.70        14
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.96      0.69      0.81        36
#                  LINES/TUBES/DRAINS       0.97      0.95      0.96        39
#           LUNG/PLEURA/LARGE AIRWAYS       0.78      0.97      0.86        95
#                       MISCELLANEOUS       0.75      0.62      0.68        24
#             POSITIONING/LIMITATIONS       0.78      0.58      0.67        12
#
#                            accuracy                           0.84       220
#                           macro avg       0.86      0.73      0.78       220
#                        weighted avg       0.85      0.84      0.83       220
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       1.00      0.67      0.80         9
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.94      0.74      0.83        23
#                  LINES/TUBES/DRAINS       0.96      0.96      0.96        47
#           LUNG/PLEURA/LARGE AIRWAYS       0.88      0.99      0.93        99
#                       MISCELLANEOUS       0.84      0.81      0.83        32
#             POSITIONING/LIMITATIONS       1.00      0.70      0.82        10
#
#                            accuracy                           0.90       220
#                           macro avg       0.94      0.81      0.86       220
#                        weighted avg       0.91      0.90      0.90       220
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       0.50      0.25      0.33         8
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.92      0.73      0.81        30
#                  LINES/TUBES/DRAINS       0.87      0.88      0.88        52
#           LUNG/PLEURA/LARGE AIRWAYS       0.84      0.97      0.90        95
#                       MISCELLANEOUS       0.70      0.58      0.64        24
#             POSITIONING/LIMITATIONS       0.78      0.64      0.70        11
#
#                            accuracy                           0.83       220
#                           macro avg       0.77      0.68      0.71       220
#                        weighted avg       0.82      0.83      0.82       220
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       1.00      0.73      0.84        11
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.96      0.75      0.84        32
#                  LINES/TUBES/DRAINS       0.94      0.83      0.88        41
#           LUNG/PLEURA/LARGE AIRWAYS       0.83      0.98      0.90        96
#                       MISCELLANEOUS       0.86      0.77      0.81        31
#             POSITIONING/LIMITATIONS       0.80      0.89      0.84         9
#
#                            accuracy                           0.87       220
#                           macro avg       0.90      0.82      0.85       220
#                        weighted avg       0.88      0.87      0.87       220
#
#                                      precision    recall  f1-score   support
#
#                BONE AND SOFT TISSUE       1.00      0.82      0.90        11
# CARDIAC/CARDIOMEDIASTINALSILHOUETTE       0.96      0.77      0.85        30
#                  LINES/TUBES/DRAINS       0.93      0.87      0.90        45
#           LUNG/PLEURA/LARGE AIRWAYS       0.84      0.98      0.91        98
#                       MISCELLANEOUS       0.92      0.75      0.83        32
#             POSITIONING/LIMITATIONS       0.80      1.00      0.89         4
#
#                            accuracy                           0.89       220
#                           macro avg       0.91      0.86      0.88       220
#                        weighted avg       0.89      0.89      0.88       220

# %%
np.mean(np.array(accuracies))
# Out:
# 0.8575771287535993
