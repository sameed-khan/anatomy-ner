# %% [markdown]
# ### Preprocess Eval Dataset
#
# __05/19/2024__
# - Modifies some mislabeling within `eval_dataset_web_05-15`
# - Merges `eval_dataset_web_05-15` with `old_annotations` from original labeling analysis with out-of-the-box LLMs

# %%
import polars as pl

pl.Config.set_tbl_cols(10)
pl.Config.set_tbl_rows(100)
# Out:
# polars.config.Config

# %%
new_dataset = (
    pl.read_csv("../../data/eval_dataset_web_05-15-2024__19-46.tsv", separator="\t")
    .filter(pl.col("labeled") == "true")
)
print(new_dataset.shape)
new_dataset.head()
# Out:
# (1663, 7)
# shape: (5, 7)
# ┌───────────────┬────────────┬──────────────┬──────────────┬──────────────┬──────────────┬─────────┐
# │ filename      ┆ patient_id ┆ finding      ┆ anatomic_cla ┆ possible_sec ┆ autogenerate ┆ labeled │
# │ ---           ┆ ---        ┆ ---          ┆ ssification  ┆ ondary       ┆ d            ┆ ---     │
# │ str           ┆ str        ┆ str          ┆ ---          ┆ ---          ┆ ---          ┆ bool    │
# │               ┆            ┆              ┆ str          ┆ str          ┆ bool         ┆         │
# ╞═══════════════╪════════════╪══════════════╪══════════════╪══════════════╪══════════════╪═════════╡
# │ mimic_cxr_rep ┆ p17504630  ┆ The patient  ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ orts/p17/p175 ┆            ┆ is status    ┆ S            ┆              ┆              ┆         │
# │ 0463…         ┆            ┆ post cor…    ┆              ┆              ┆              ┆         │
# │ mimic_cxr_rep ┆ p17504630  ┆ The heart is ┆ HEART        ┆ HEART        ┆ true         ┆ true    │
# │ orts/p17/p175 ┆            ┆ mildly       ┆              ┆              ┆              ┆         │
# │ 0463…         ┆            ┆ enlarged     ┆              ┆              ┆              ┆         │
# │ mimic_cxr_rep ┆ p17504630  ┆ The cardiac, ┆ MEDIASTINUM  ┆ MEDIASTINUM  ┆ true         ┆ true    │
# │ orts/p17/p175 ┆            ┆ mediastinal  ┆ AND HILA     ┆ AND HILA     ┆              ┆         │
# │ 0463…         ┆            ┆ and h…       ┆              ┆              ┆              ┆         │
# │ mimic_cxr_rep ┆ p17504630  ┆ Opacificatio ┆ LUNG/PLEURA/ ┆ LUNG/PLEURA/ ┆ true         ┆ true    │
# │ orts/p17/p175 ┆            ┆ n at the     ┆ LARGE        ┆ LARGE        ┆              ┆         │
# │ 0463…         ┆            ┆ left lung…   ┆ AIRWAYS      ┆ AIRWAYS      ┆              ┆         │
# │ mimic_cxr_rep ┆ p17504630  ┆ A small      ┆ LINES/TUBES/ ┆ LINES/TUBES/ ┆ true         ┆ true    │
# │ orts/p17/p175 ┆            ┆ caliber      ┆ DRAINS       ┆ DRAINS       ┆              ┆         │
# │ 0463…         ┆            ┆ chest tube   ┆              ┆              ┆              ┆         │
# │               ┆            ┆ at…          ┆              ┆              ┆              ┆         │
# └───────────────┴────────────┴──────────────┴──────────────┴──────────────┴──────────────┴─────────┘

# %% [markdown]
# Some categories might be redundant

# %%
new_dataset["anatomic_classification"].unique()
# Out:
# shape: (17,)
# Series: 'anatomic_classification' [str]
# [
# 	"STOMACH"
# 	"ABDOMEN"
# 	"POSITIONING/LIMITATIONS"
# 	"BONE"
# 	"MEDIASTINUM AND HILA"
# 	"MISCELLANEOUS"
# 	"CARDIAC/CARDIOMEDIASTINALSILHO…
# 	"BOWEL"
# 	"LINES/TUBES/DRAINS"
# 	"POSITIONING"
# 	"HEART"
# 	"LUNG/PLEURA/LARGE AIRWAYS"
# 	"LUNG"
# 	"BONE AND SOFT TISSUE"
# 	"GALLBLADDER"
# 	"SPLEEN"
# 	"NECK"
# ]

# %% [markdown]
# We will merge `LUNG` with `LUNG/PLEURA/LARGE AIRWAYS` as well as merge various other labels with each other.

# %%
new_dataset = new_dataset.with_columns(
    pl.when(pl.col("anatomic_classification") == "LUNG")
        .then(pl.lit("LUNG/PLEURA/LARGE AIRWAYS"))
        .when(pl.col("anatomic_classification") == "HEART")
        .then(pl.lit("CARDIAC/CARDIOMEDIASTINALSILHOUETTE"))
        .when(pl.col("anatomic_classification") == "POSITIONING")
        .then(pl.lit("POSITIONING/LIMITATIONS"))
        .when(pl.col("anatomic_classification") == "BONE")
        .then(pl.lit("BONE AND SOFT TISSUE"))
        .when(pl.col("anatomic_classification") == "MEDIASTINUM AND HILA")  # This switch might need to be manually checked later
        .then(pl.lit("CARDIAC/CARDIOMEDIASTINALSILHOUETTE"))
        .otherwise(pl.col("anatomic_classification"))
        .alias("anatomic_classification")
)
new_dataset["anatomic_classification"].unique()
# Out:
# shape: (12,)
# Series: 'anatomic_classification' [str]
# [
# 	"LUNG/PLEURA/LARGE AIRWAYS"
# 	"STOMACH"
# 	"CARDIAC/CARDIOMEDIASTINALSILHO…
# 	"GALLBLADDER"
# 	"ABDOMEN"
# 	"NECK"
# 	"BONE AND SOFT TISSUE"
# 	"LINES/TUBES/DRAINS"
# 	"MISCELLANEOUS"
# 	"SPLEEN"
# 	"BOWEL"
# 	"POSITIONING/LIMITATIONS"
# ]

# %% [markdown]
# Now we merge with the old annotations.

# %%
old_dataset = (
    pl.read_csv("../../data/old_annotations.tsv", separator="\t")
)
old_dataset.head()
# Out:
# shape: (5, 5)
# ┌─────────────────────┬────────────┬─────────────────────┬────────────────────┬────────────────────┐
# │ filename            ┆ patient_id ┆ finding             ┆ anatomic_classific ┆ possible_secondary │
# │ ---                 ┆ ---        ┆ ---                 ┆ ation              ┆ ---                │
# │ str                 ┆ str        ┆ str                 ┆ ---                ┆ str                │
# │                     ┆            ┆                     ┆ str                ┆                    │
# ╞═════════════════════╪════════════╪═════════════════════╪════════════════════╪════════════════════╡
# │ /home/khans24/chari ┆ p10394761  ┆ PA and lateral      ┆ MISCELLANEOUS      ┆ null               │
# │ t/anatomy_n…        ┆            ┆ chest views wer…    ┆                    ┆                    │
# │ /home/khans24/chari ┆ p10394761  ┆ Analysis is         ┆ MISCELLANEOUS      ┆ null               │
# │ t/anatomy_n…        ┆            ┆ performed in direc… ┆                    ┆                    │
# │ /home/khans24/chari ┆ p10394761  ┆ There is mild       ┆ HEART              ┆ null               │
# │ t/anatomy_n…        ┆            ┆ cardiac enlargem…   ┆                    ┆                    │
# │ /home/khans24/chari ┆ p10394761  ┆ There is  a         ┆ HEART              ┆ null               │
# │ t/anatomy_n…        ┆            ┆ relative prominenc… ┆                    ┆                    │
# │ /home/khans24/chari ┆ p10394761  ┆ The  thoracic aorta ┆ HEART              ┆ null               │
# │ t/anatomy_n…        ┆            ┆ is general…         ┆                    ┆                    │
# └─────────────────────┴────────────┴─────────────────────┴────────────────────┴────────────────────┘

# %% [markdown]
# We will add the `labeled` and `autogenerated` columns to this dataset

# %%
old_dataset = old_dataset.with_columns(
    autogenerated = False,
    labeled = True
)
old_dataset.head()
# Out:
# shape: (5, 7)
# ┌───────────────┬────────────┬──────────────┬──────────────┬──────────────┬──────────────┬─────────┐
# │ filename      ┆ patient_id ┆ finding      ┆ anatomic_cla ┆ possible_sec ┆ autogenerate ┆ labeled │
# │ ---           ┆ ---        ┆ ---          ┆ ssification  ┆ ondary       ┆ d            ┆ ---     │
# │ str           ┆ str        ┆ str          ┆ ---          ┆ ---          ┆ ---          ┆ bool    │
# │               ┆            ┆              ┆ str          ┆ str          ┆ bool         ┆         │
# ╞═══════════════╪════════════╪══════════════╪══════════════╪══════════════╪══════════════╪═════════╡
# │ /home/khans24 ┆ p10394761  ┆ PA and       ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ lateral      ┆ S            ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ chest views  ┆              ┆              ┆              ┆         │
# │               ┆            ┆ wer…         ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ Analysis is  ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ performed in ┆ S            ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ direc…       ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ There is     ┆ HEART        ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ mild cardiac ┆              ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ enlargem…    ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ There is  a  ┆ HEART        ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ relative     ┆              ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ prominenc…   ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ The          ┆ HEART        ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ thoracic     ┆              ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ aorta is     ┆              ┆              ┆              ┆         │
# │               ┆            ┆ general…     ┆              ┆              ┆              ┆         │
# └───────────────┴────────────┴──────────────┴──────────────┴──────────────┴──────────────┴─────────┘

# %% [markdown]
# Perform the appropriate relabeling...

# %%
old_dataset["anatomic_classification"].unique()
# Out:
# shape: (7,)
# Series: 'anatomic_classification' [str]
# [
# 	"HEART"
# 	"POSITIONING/LIMITATIONS"
# 	"MISCELLANEOUS"
# 	"BONE AND SOFT TISSUE"
# 	"LUNG/PLEURA/LARGE AIRWAYS"
# 	"BOWEL"
# 	"LINES/TUBES/DRAINS"
# ]

# %%
old_dataset = old_dataset.with_columns(
    pl.when(pl.col("anatomic_classification") == "HEART")
        .then(pl.lit("CARDIAC/CARDIOMEDIASTINALSILHOUETTE"))
        .otherwise(pl.col("anatomic_classification"))
        .alias("anatomic_classification")
)
old_dataset["anatomic_classification"].unique()
# Out:
# shape: (7,)
# Series: 'anatomic_classification' [str]
# [
# 	"BONE AND SOFT TISSUE"
# 	"MISCELLANEOUS"
# 	"CARDIAC/CARDIOMEDIASTINALSILHO…
# 	"BOWEL"
# 	"POSITIONING/LIMITATIONS"
# 	"LUNG/PLEURA/LARGE AIRWAYS"
# 	"LINES/TUBES/DRAINS"
# ]

# %%
final_df = pl.concat([old_dataset, new_dataset])
final_df.head()
# Out:
# shape: (5, 7)
# ┌───────────────┬────────────┬──────────────┬──────────────┬──────────────┬──────────────┬─────────┐
# │ filename      ┆ patient_id ┆ finding      ┆ anatomic_cla ┆ possible_sec ┆ autogenerate ┆ labeled │
# │ ---           ┆ ---        ┆ ---          ┆ ssification  ┆ ondary       ┆ d            ┆ ---     │
# │ str           ┆ str        ┆ str          ┆ ---          ┆ ---          ┆ ---          ┆ bool    │
# │               ┆            ┆              ┆ str          ┆ str          ┆ bool         ┆         │
# ╞═══════════════╪════════════╪══════════════╪══════════════╪══════════════╪══════════════╪═════════╡
# │ /home/khans24 ┆ p10394761  ┆ PA and       ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ lateral      ┆ S            ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ chest views  ┆              ┆              ┆              ┆         │
# │               ┆            ┆ wer…         ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ Analysis is  ┆ MISCELLANEOU ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ performed in ┆ S            ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ direc…       ┆              ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ There is     ┆ CARDIAC/CARD ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ mild cardiac ┆ IOMEDIASTINA ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ enlargem…    ┆ LSILHO…      ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ There is  a  ┆ CARDIAC/CARD ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ relative     ┆ IOMEDIASTINA ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ prominenc…   ┆ LSILHO…      ┆              ┆              ┆         │
# │ /home/khans24 ┆ p10394761  ┆ The          ┆ CARDIAC/CARD ┆ null         ┆ false        ┆ true    │
# │ /charit/anato ┆            ┆ thoracic     ┆ IOMEDIASTINA ┆              ┆              ┆         │
# │ my_n…         ┆            ┆ aorta is     ┆ LSILHO…      ┆              ┆              ┆         │
# │               ┆            ┆ general…     ┆              ┆              ┆              ┆         │
# └───────────────┴────────────┴──────────────┴──────────────┴──────────────┴──────────────┴─────────┘

# %%
final_df["anatomic_classification"].unique()
# Out:
# shape: (12,)
# Series: 'anatomic_classification' [str]
# [
# 	"LINES/TUBES/DRAINS"
# 	"STOMACH"
# 	"BONE AND SOFT TISSUE"
# 	"MISCELLANEOUS"
# 	"BOWEL"
# 	"ABDOMEN"
# 	"POSITIONING/LIMITATIONS"
# 	"NECK"
# 	"CARDIAC/CARDIOMEDIASTINALSILHO…
# 	"SPLEEN"
# 	"GALLBLADDER"
# 	"LUNG/PLEURA/LARGE AIRWAYS"
# ]

# %%
final_df.shape
# Out:
# (2230, 7)

# %%
final_df.write_csv("../../data/eval_dataset_2000.tsv", separator="\t")
